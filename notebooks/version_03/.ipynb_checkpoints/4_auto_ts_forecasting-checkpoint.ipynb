# %% [markdown]
# # Advanced time series forecasting with FEDOT. Guide
# #### FEDOT version = 0.3
#
# [Original repository on GitHub](https://github.com/nccr-itmo/FEDOT)
#
# This tutorial was prepared by [Natural Systems Simulation Team](https://github.com/ITMO-NSS-team)
#
# ---
#
# Below is an example of how you can use advanced ways to configure FEDOT for a time series forecasting task.
#
# If you want to learn some basic things about FEDOT and time series forecasting, you can use [this notebook](3_intro_ts_forecasting.ipynb).

# %%
# Additional imports 
import pandas as pd 
import numpy as np

# Imports for creating plots
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 18, 7

# Import data
df = pd.read_csv('../data/ts_traffic.csv')
df['datetime'] = pd.to_datetime(df['datetime'])

# Plot data
df.plot('datetime', 'value')
plt.show()

print(f'Length of the time series - {len(df)}')
# Out:
# Length of the time series - 801

# %% [markdown]
# Data: hourly traffic volume values. From the plot, you can see 2 peaks for each cycle: morning and evening, as well as a decrease in traffic on weekends.

# %% [markdown]
# ## Manualy created chain

# %%
# Chain and nodes
from fedot.core.chains.chain import Chain
from fedot.core.chains.node import PrimaryNode, SecondaryNode

# Data 
from fedot.core.data.data import InputData
from fedot.core.data.data import train_test_data_setup
from fedot.core.repository.dataset_types import DataTypesEnum

# Tasks
from fedot.core.repository.tasks import Task, TaskTypesEnum, TsForecastingParams

# Metric
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# Let's imagine that we need to predict the traffic volume for 72 hours ahead.

# %%
forecast_length = 72

# %%
# Wrapp data into InputData
task = Task(TaskTypesEnum.ts_forecasting,
                TsForecastingParams(forecast_length=forecast_length))

# Get time series from dataframe
traffic = np.array(df['value'])
input_data = InputData(idx=np.arange(0, len(traffic)),
                       features=traffic,
                       target=traffic,
                       task=task,
                       data_type=DataTypesEnum.ts)

# Split data into train and test
train_input, predict_input = train_test_data_setup(input_data)

# %% [markdown]
# Let's create a function for configuring complex chains and a function to plot results.

# %%
def get_two_branches_chain(lagged_param_1=10, lagged_param_2=10,
                           model_1='ridge', model_2='ridge', model_3='ridge'):
    """
    Chain looking like this
    lagged -> model_1 \
                       \
                        model_3 -> final forecast
                       /
    lagged -> model_2 /
    """
    # First level
    node_lagged_1 = PrimaryNode('lagged')
    node_lagged_1.custom_params = {'window_size': lagged_param_1}
    node_lagged_2 = PrimaryNode('lagged')
    node_lagged_2.custom_params = {'window_size': lagged_param_2}

    # Second level
    node_second_1 = SecondaryNode(model_1, nodes_from=[node_lagged_1])
    node_second_2 = SecondaryNode(model_2, nodes_from=[node_lagged_2])

    # Third level - root node
    node_final = SecondaryNode(model_3, nodes_from=[node_second_1, node_second_2])
    chain = Chain(node_final)
    
    return chain


def plot_results(actual_time_series, predicted_values, len_train_data, y_name = 'Parameter'):
    """
    Function for drawing plot with predictions
    
    :param actual_time_series: the entire array with one-dimensional data
    :param predicted_values: array with predicted values
    :param len_train_data: number of elements in the training sample
    :param y_name: name of the y axis
    """
    
    plt.plot(np.arange(0, len(actual_time_series)), 
             actual_time_series, label = 'Actual values', c = 'green')
    plt.plot(np.arange(len_train_data, len_train_data + len(predicted_values)), 
             predicted_values, label = 'Predicted', c = 'blue')
    # Plot black line which divide our array into train and test
    plt.plot([len_train_data, len_train_data],
             [min(actual_time_series), max(actual_time_series)], c = 'black', linewidth = 1)
    plt.ylabel(y_name, fontsize = 15)
    plt.xlabel('Time index', fontsize = 15)
    plt.legend(fontsize = 15, loc='upper left')
    plt.grid()
    plt.show()

# %% [markdown]
# This time series is quite simple for an expert to interpret. So we can use our knowledge of cycling to set the lags manually.
#
# Lags here are:
# * 144 elements
# * 12 elements

# %%
# Initialise chain for making forecasting
chain = get_two_branches_chain(lagged_param_1=144, 
                               lagged_param_2=12)

# Fit
chain.fit(train_input)

# Make forecast
output = chain.predict(predict_input)
forecast = np.ravel(np.array(output.predict))

# %% [markdown]
# ### Manual chain forecast

# %%
plot_results(actual_time_series = traffic,
             predicted_values = forecast, 
             len_train_data = len(traffic)-forecast_length)

# Print MAE metric
print(f'Mean absolute error: {mean_absolute_error(predict_input.target, forecast):.3f}')
# Out:
# Mean absolute error: 454.551

# %% [markdown]
# To complicate the task, imagine that we don't know anything about the time series structure. Let's try to find optimal parameters using the algorithm for configuring hyperparameters in the nodes.
#
# ## Hyperparameters tuning
#
# To configure hyperparameters, you can use 2 approaches: sequential (1) and simultaneous (2) tuning. Below are the animations of how the hyperparameters optimization is performed.
#
# ![sequental_tuning.gif](../jupyter_media/time_series/sequental_tuning.gif)
#
# (1) Animation of sequential tuning
#
# ![chain_tuning.gif](../jupyter_media/time_series/chain_tuning.gif)
#
# (2) Animation of simultaneous tuning
#
# Below, we will use the ChainTuner class to configure hyperparameters in the chain nodes. This tuning is simultaneous tuning.

# %%
from fedot.core.chains.tuning.unified import ChainTuner

init_chain = get_two_branches_chain()

# Call ChainTuner
chain_tuner = ChainTuner(chain=init_chain, 
                         task=task,
                         iterations=50)

tuned_chain = chain_tuner.tune_chain(input_data=train_input,
                                     loss_function=mean_absolute_error,
                                     loss_params=None)

tuned_output = tuned_chain.predict(predict_input)
tuned_forecast = np.ravel(np.array(tuned_output.predict))


plot_results(actual_time_series = traffic,
             predicted_values = tuned_forecast, 
             len_train_data = len(traffic)-forecast_length)

# Print MAE metric
print(f'Mean absolute error: {mean_absolute_error(predict_input.target, tuned_forecast):.3f}')
# Out:
# Hyperparameters optimization start
# Fit chain from scratch
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]Fit chain from scratch
#   2%|█                                                 | 1/50 [00:01<01:14,  1.51s/trial, best loss: 280.2876908047813]Fit chain from scratch
#   4%|██                                                | 2/50 [00:02<00:53,  1.11s/trial, best loss: 280.2876908047813]Fit chain from scratch
#   6%|██▉                                              | 3/50 [00:03<00:49,  1.06s/trial, best loss: 262.41211547983795]Fit chain from scratch
# Fit chain from scratch
# Hyperparameters optimization finished
# Return tuned chain due to the fact that obtained metric 262.412 equal or smaller than initial (+ 5% deviation) 892.321
# Mean absolute error: 389.505

# %% [markdown]
# We can also use the same approach, but with a different interface. Calling the "fine_tune_all_nodes" method

# %%
init_chain = get_two_branches_chain()

# Start tuning all nodes in the chain 
tuned_chain = init_chain.fine_tune_all_nodes(loss_function=mean_absolute_error,
                                             loss_params=None,
                                             input_data=train_input,
                                             iterations=50)

# Make prediction
tuned_output = tuned_chain.predict(predict_input)
tuned_forecast = np.ravel(np.array(tuned_output.predict))


plot_results(actual_time_series = traffic,
             predicted_values = tuned_forecast, 
             len_train_data = len(traffic)-forecast_length)

# Print MAE metric
print(f'Mean absolute error: {mean_absolute_error(predict_input.target, tuned_forecast):.3f}')
# Out:
# Start tuning of primary nodes
# Hyperparameters optimization start
# Fit chain from scratch
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]Fit chain from scratch
#   2%|█                                                 | 1/50 [00:00<00:34,  1.43trial/s, best loss: 608.6972685968016]Fit chain from scratch
#   4%|█▉                                               | 2/50 [00:01<00:37,  1.30trial/s, best loss: 284.31322878922145]Fit chain from scratch
#   6%|███                                               | 3/50 [00:02<00:39,  1.19trial/s, best loss: 281.1085179258994]Fit chain from scratch
#   8%|████                                              | 4/50 [00:03<00:46,  1.01s/trial, best loss: 281.1085179258994]Fit chain from scratch
#  10%|█████                                             | 5/50 [00:04<00:37,  1.21trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  12%|██████                                            | 6/50 [00:04<00:35,  1.25trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  14%|███████                                           | 7/50 [00:05<00:32,  1.34trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  16%|████████                                          | 8/50 [00:06<00:27,  1.54trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  18%|█████████                                         | 9/50 [00:06<00:27,  1.52trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  20%|█████████▊                                       | 10/50 [00:07<00:31,  1.26trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  22%|██████████▊                                      | 11/50 [00:08<00:31,  1.25trial/s, best loss: 281.1085179258994]Fit chain from scratch
#  24%|███████████▊                                     | 12/50 [00:10<00:38,  1.02s/trial, best loss: 276.6687480695287]Fit chain from scratch
#  26%|████████████▋                                    | 13/50 [00:11<00:36,  1.00trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  28%|█████████████▋                                   | 14/50 [00:12<00:40,  1.13s/trial, best loss: 276.6687480695287]Fit chain from scratch
#  30%|██████████████▋                                  | 15/50 [00:13<00:42,  1.22s/trial, best loss: 276.6687480695287]Fit chain from scratch
#  32%|███████████████▋                                 | 16/50 [00:14<00:32,  1.05trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  34%|████████████████▋                                | 17/50 [00:14<00:26,  1.23trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  82%|████████████████████████████████████████▏        | 41/50 [00:35<00:07,  1.14trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  84%|█████████████████████████████████████████▏       | 42/50 [00:36<00:06,  1.19trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  86%|██████████████████████████████████████████▏      | 43/50 [00:36<00:05,  1.23trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  88%|███████████████████████████████████████████      | 44/50 [00:38<00:05,  1.14trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  90%|████████████████████████████████████████████     | 45/50 [00:39<00:05,  1.06s/trial, best loss: 276.6687480695287]Fit chain from scratch
#  92%|█████████████████████████████████████████████    | 46/50 [00:40<00:03,  1.02trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  94%|██████████████████████████████████████████████   | 47/50 [00:41<00:03,  1.03s/trial, best loss: 276.6687480695287]Fit chain from scratch
#  96%|███████████████████████████████████████████████  | 48/50 [00:41<00:01,  1.18trial/s, best loss: 276.6687480695287]Fit chain from scratch
#  98%|████████████████████████████████████████████████ | 49/50 [00:42<00:00,  1.21trial/s, best loss: 276.6687480695287]Fit chain from scratch
# 100%|█████████████████████████████████████████████████| 50/50 [00:43<00:00,  1.16trial/s, best loss: 276.6687480695287]
# Fit chain from scratch
# Hyperparameters optimization finished
# Return tuned chain due to the fact that obtained metric 276.669 equal or smaller than initial (+ 5% deviation) 892.321
# Tuning was finished
# Mean absolute error: 374.472

# %% [markdown]
# Let's look at the hyperparameters found in the nodes.

# %%
def display_chain_info(chain):
    """ Function print info about chain """

    print('Obtained chain:')
    for node in chain.nodes:
        print(f'{node.operation.operation_type}, params: {node.custom_params}')
    depth = int(chain.depth)
    print(f'Chain depth {depth}\n')

# Print hyperparameters for all nodes
display_chain_info(tuned_chain)
# Out:
# Obtained chain:
# ridge, params: {'alpha': 6.803557156137253}
# ridge, params: {'alpha': 4.978284677747284}
# lagged, params: {'window_size': 480.0345474869811}
# ridge, params: {'alpha': 5.0562000112048695}
# lagged, params: {'window_size': 469.42191250692406}
# Chain depth 3

# %% [markdown]
# Thus, when using optimization, we were able to surpass the "expert approach" to determining hyperparameters.
#
# But what if we do not know not only nothing about the appropriate parameters in the nodes, but also do not know what structure the chain should be for forecasting. In this case, we can use composer.
#
# ## Time series chain composing

# %%
import datetime

# Import fedot composer and supplementary classes 
from fedot.core.composer.gp_composer.gp_composer import \
    GPComposerBuilder, GPComposerRequirements
from fedot.core.composer.optimisers.gp_comp.gp_optimiser import GPChainOptimiserParameters
from fedot.core.composer.optimisers.gp_comp.operators.mutation import MutationTypesEnum
from fedot.core.composer.visualisation import ChainVisualiser
from fedot.core.repository.quality_metrics_repository import \
    MetricsRepository, RegressionMetricsEnum
from fedot.core.repository.tasks import Task, TaskTypesEnum, TsForecastingParams

# %% [markdown]
# We can determine which models and data operations we will use to predict the time series, in this case we will use:
# * lagged - lagged transformation time series into table form;
# * smoothing - moving average smoothing of time series;
# * gaussian_filter - smoothing of time series;
# * ar - two-lag autoregression model;
#
#
# * ridge - ridge regression;
# * lasso - lasso regression;
# * linear - linear model;
# * knnreg - regression based on k-nearest neighbors;
# * dtreg - decision tree regression;
# * scaling - scaling operation;
# * ransac_lin_reg - RANSAC (RANdom SAmple Consensus) algorithm with linear regression as base estimator;
# * ransac_non_lin_reg - RANSAC (RANdom SAmple Consensus) algorithm with decision tree regression as base estimator;
# * rfe_lin_reg - feature ranking with recursive feature elimination with linear regression as base estimator;
# * rfe_non_lin_reg - feature ranking with recursive feature elimination with decision tree regression as base estimator.

# %%
primary_operations = ['lagged', 'smoothing', 'gaussian_filter', 'ar']
secondary_operations = ['lagged', 'ridge', 'lasso', 'knnreg', 'dtreg', 
                        'linear', 'scaling', 'ransac_lin_reg', 'ransac_non_lin_reg', 
                        'rfe_lin_reg', 'rfe_non_lin_reg']

# %%
# Composer parameters
composer_requirements = GPComposerRequirements(
    primary=primary_operations,
    secondary=secondary_operations, max_arity=3,
    max_depth=8, pop_size=10, num_of_generations=15,
    crossover_prob=0.8, mutation_prob=0.8,
    max_lead_time=datetime.timedelta(minutes=10),
    allow_single_operations=False)

# %% [markdown]
# ### Hyperparameters search during composing

# %%
mutation_types = [MutationTypesEnum.parameter_change, MutationTypesEnum.simple, MutationTypesEnum.reduce]
optimiser_parameters = GPChainOptimiserParameters(mutation_types=mutation_types)

# %%
metric_function = MetricsRepository().metric_by_id(RegressionMetricsEnum.MAE)
builder = GPComposerBuilder(task=task). \
    with_optimiser_parameters(optimiser_parameters).\
    with_requirements(composer_requirements).\
    with_metrics(metric_function).with_initial_chain(init_chain)
composer = builder.build()

obtained_chain = composer.compose_chain(data=train_input, is_visualise=False)
# Out:
# Best metric is 276.6687480695287
# Generation num: 0
# max_depth: 8, no improvements: 0
# spent time: 0.3 min
# Best metric is 275.1686516719761
# Generation num: 1
# max_depth: 8, no improvements: 0
# spent time: 0.4 min
# Best metric is 274.8796760394695
# Generation num: 2
# max_depth: 8, no improvements: 0
# spent time: 0.6 min
# Best metric is 274.8796760394695
# Generation num: 3
# max_depth: 8, no improvements: 1
# spent time: 0.8 min
# Best metric is 256.13532987876454
# Generation num: 4
# max_depth: 8, no improvements: 0
# spent time: 1.0 min
# Best metric is 256.13532987876454
# Generation num: 5
# max_depth: 8, no improvements: 1
# spent time: 1.2 min
# Best metric is 208.88885507899928
# Generation num: 6
# max_depth: 8, no improvements: 0
# spent time: 1.5 min
# Best metric is 208.88885507899928
# Generation num: 7
# max_depth: 8, no improvements: 1
# spent time: 1.9 min
# Best metric is 177.83332004269818
# Generation num: 8
# max_depth: 8, no improvements: 0
# spent time: 2.0 min
# Best metric is 177.83332004269818
# Generation num: 9
# max_depth: 8, no improvements: 1
# spent time: 2.2 min
# Best metric is 177.83332004269818
# Generation num: 10
# max_depth: 8, no improvements: 2
# spent time: 2.3 min
# Best metric is 177.83332004269818
# Generation num: 11
# max_depth: 8, no improvements: 3
# Chain assessment warning: `min_samples` may not be larger than number of samples: n_samples = 106.. Continue.
# spent time: 2.4 min
# Best metric is 177.83332004269818
# Generation num: 12
# max_depth: 8, no improvements: 4
# spent time: 2.5 min
# Best metric is 177.83332004269818
# Generation num: 13
# max_depth: 8, no improvements: 5
# Chain assessment warning: RANSAC could not find a valid consensus set. All `max_trials` iterations were skipped because each randomly chosen sub-sample failed the passing criteria. See estimator attributes for diagnostics (n_skips*).. Continue.
# spent time: 2.6 min
# Best metric is 143.8610849868334
# Result:
# Best metric is 143.8610849868334
# Composition time: 2.619 min
# GP composition finished

# %%
# Make prediction
obtained_output = obtained_chain.predict(predict_input)
obtained_forecast = np.ravel(np.array(obtained_output.predict))


plot_results(actual_time_series = traffic,
             predicted_values = obtained_forecast, 
             len_train_data = len(traffic)-forecast_length)

# Print MAE metric
print(f'Mean absolute error: {mean_absolute_error(predict_input.target, obtained_forecast):.3f}')
# Out:
# Mean absolute error: 981.667

# %% [markdown]
# ## Chain visualization and saving

# %%
visualiser = ChainVisualiser()
visualiser.visualise(obtained_chain)

# %%
# Print hyperparameters for all nodes
display_chain_info(obtained_chain)
# Out:
# Obtained chain:
# ridge, params: {'alpha': 6.803557156137253}
# lagged, params: default_params
# dtreg, params: default_params
# ridge, params: {'alpha': 4.978284677747284}
# ridge, params: {'alpha': 6.803557156137253}
# lagged, params: {'window_size': 436.48052158607493}
# dtreg, params: default_params
# ridge, params: {'alpha': 4.978284677747284}
# lagged, params: default_params
# lagged, params: default_params
# lagged, params: default_params
# Chain depth 7

# %% [markdown]
# ## Final tuning

# %%
from sklearn.metrics import mean_squared_error

obtained_chain = obtained_chain.fine_tune_all_nodes(loss_function=mean_squared_error,
                                                    loss_params={'squared': False},
                                                    input_data=train_input,
                                                    iterations=50)

# Make prediction
obtained_output = obtained_chain.predict(predict_input)
obtained_forecast = np.ravel(np.array(obtained_output.predict))


plot_results(actual_time_series = traffic,
             predicted_values = obtained_forecast, 
             len_train_data = len(traffic)-forecast_length)

# Print MAE metric
print(f'Mean absolute error: {mean_absolute_error(predict_input.target, obtained_forecast):.3f}')
# Out:
# Start tuning of primary nodes
# Hyperparameters optimization start
# Fit chain from scratch
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]Fit chain from scratch
#   2%|█                                                 | 1/50 [00:01<01:16,  1.56s/trial, best loss: 446.1783357933447]Fit chain from scratch
#   4%|██                                                | 2/50 [00:03<01:30,  1.89s/trial, best loss: 446.1783357933447]Fit chain from scratch
#   6%|███                                               | 3/50 [00:04<01:09,  1.49s/trial, best loss: 446.1783357933447]Fit chain from scratch
#   8%|████                                              | 4/50 [00:06<01:09,  1.50s/trial, best loss: 446.1783357933447]Fit chain from scratch
#  10%|████▉                                            | 5/50 [00:08<01:27,  1.94s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  12%|█████▉                                           | 6/50 [00:10<01:23,  1.89s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  14%|██████▊                                          | 7/50 [00:12<01:18,  1.83s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  16%|███████▊                                         | 8/50 [00:14<01:21,  1.93s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  18%|████████▊                                        | 9/50 [00:16<01:19,  1.94s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  20%|█████████▌                                      | 10/50 [00:17<01:10,  1.75s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  22%|██████████▌                                     | 11/50 [00:19<01:03,  1.63s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  24%|███████████▌                                    | 12/50 [00:20<00:56,  1.48s/trial, best loss: 430.96533299652697]Fit chain from scratch
#  26%|████████████▍                                   | 13/50 [00:22<01:03,  1.72s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  28%|█████████████▍                                  | 14/50 [00:23<00:56,  1.56s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  30%|██████████████▍                                 | 15/50 [00:25<00:57,  1.65s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  32%|███████████████▎                                | 16/50 [00:27<01:02,  1.84s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  34%|████████████████▎                               | 17/50 [00:29<01:00,  1.84s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  36%|█████████████████▎                              | 18/50 [00:31<00:57,  1.81s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  38%|██████████████████▏                             | 19/50 [00:33<01:00,  1.94s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  40%|███████████████████▏                            | 20/50 [00:35<00:56,  1.87s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  42%|████████████████████▏                           | 21/50 [00:37<00:55,  1.92s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  44%|█████████████████████                           | 22/50 [00:39<00:52,  1.87s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  46%|██████████████████████                          | 23/50 [00:41<00:51,  1.91s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  48%|███████████████████████                         | 24/50 [00:42<00:46,  1.81s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  50%|████████████████████████                        | 25/50 [00:44<00:47,  1.89s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  52%|████████████████████████▉                       | 26/50 [00:47<00:47,  1.97s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  54%|█████████████████████████▉                      | 27/50 [00:49<00:49,  2.15s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  56%|██████████████████████████▉                     | 28/50 [00:51<00:46,  2.10s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  58%|███████████████████████████▊                    | 29/50 [00:53<00:41,  1.98s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  60%|████████████████████████████▊                   | 30/50 [00:55<00:40,  2.05s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  62%|█████████████████████████████▊                  | 31/50 [00:57<00:39,  2.09s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  64%|██████████████████████████████▋                 | 32/50 [00:59<00:37,  2.10s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  66%|███████████████████████████████▋                | 33/50 [01:01<00:30,  1.82s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  68%|████████████████████████████████▋               | 34/50 [01:02<00:29,  1.81s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  70%|█████████████████████████████████▌              | 35/50 [01:05<00:30,  2.03s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  72%|██████████████████████████████████▌             | 36/50 [01:07<00:30,  2.16s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  74%|███████████████████████████████████▌            | 37/50 [01:09<00:27,  2.08s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  76%|████████████████████████████████████▍           | 38/50 [01:12<00:26,  2.20s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  78%|█████████████████████████████████████▍          | 39/50 [01:14<00:23,  2.18s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  80%|██████████████████████████████████████▍         | 40/50 [01:16<00:21,  2.14s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  82%|███████████████████████████████████████▎        | 41/50 [01:18<00:19,  2.12s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  84%|████████████████████████████████████████▎       | 42/50 [01:20<00:16,  2.12s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  86%|█████████████████████████████████████████▎      | 43/50 [01:23<00:16,  2.29s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  88%|██████████████████████████████████████████▏     | 44/50 [01:24<00:12,  2.10s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  90%|███████████████████████████████████████████▏    | 45/50 [01:27<00:10,  2.15s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  92%|████████████████████████████████████████████▏   | 46/50 [01:28<00:07,  1.96s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  94%|█████████████████████████████████████████████   | 47/50 [01:30<00:05,  1.96s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  96%|██████████████████████████████████████████████  | 48/50 [01:32<00:03,  1.79s/trial, best loss: 369.80521938755993]Fit chain from scratch
#  98%|███████████████████████████████████████████████ | 49/50 [01:34<00:01,  1.92s/trial, best loss: 369.80521938755993]Fit chain from scratch
# 100%|████████████████████████████████████████████████| 50/50 [01:36<00:00,  1.93s/trial, best loss: 369.80521938755993]
# Fit chain from scratch
# Hyperparameters optimization finished
# Return init chain due to the fact that obtained metric 369.805 bigger than initial (+ 5% deviation) 321.730
# Tuning was finished
# Mean absolute error: 899.250
